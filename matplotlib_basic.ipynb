# %% [markdown]
# ### Matplotlib 기본

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])     # plt함수는 리스트의 값을 y값으로 가정. x값은 자동 생성
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])    # 이와 같이 입력하면 인덱스 0이 x값, 1이 y값

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')     # 'ro'는 red + 원형마커 'o'의미
plt.axis([0, 6, 0, 20])                         # axis() 함수는 축의 범위를 지정([xmin, xmax, ymin, ymax])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'b-')     # 'b-'는 blue + 실선 '-'의미
plt.axis([0, 6, 0, 20])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'gx')     # 'gx'는 green + 'x'의미
plt.axis([0, 6, 0, 20])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'k*')     # 'k*'는 'black' + '*'의미
plt.axis([0, 6, 0, 20])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], ':c')     # ':c'는 ':(line)' + 'cyan'의미
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ### Matplotlib 데이터 입력

# %%
data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y':[2, 3, 5, 10, 8]}
plt.plot('data_x', 'data_y', data=data_dict)

# %% [markdown]
# ### label 설정

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], '^m')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15)         # labelpad는 축 레이블의 여백을 지정
plt.ylabel('Y-Axis', labelpad=20)
plt.show()

# %% [markdown]
# ### font 설정

# %%
font1 = {'family' : 'serif', 
        'color' : 'b',
        'weight' : 'bold',
        'size' : 14
        }

font2 = {'family' : 'fantasy', 
        'color' : 'deeppink',
        'weight' : 'normal',
        'size' : 'xx-large'
        }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
plt.show()

# %% [markdown]
# ### 범례

# %%
# 범례 Legend는 그래프에 데이터의 종류를 표시하기 위한 텍스트
# legend()함수를 사용해서 그래프에 범례를 표시

# %%
# 범례를 나타내기 위해 plot()함수에 label 문자열 지정하고 legend() 함수 호출

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='lower right')            # legend()함수의 loc파라미터를 사용해 범례가 사용될 위치 설정
                                         # 위치는 문자열 혹은 숫자 코드로도 사용 가능
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# plt.legend(loc='best')
plt.legend(loc='best', ncol=2)          # legend()함수의 ncol 파라미터는 범례에 표시될 텍스트 열 개수
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.legend(loc='best', ncol=2, fontsize=14)          # fontsize파라미터로 폰트 크기 지정
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# frameon은 범례상자 테두리 여부, shadow는 그림자 추가
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
plt.show()

# %% [markdown]
# ### 축 설정

# %%
# xlim(), ylim(), axis()함수들을 사용, X,Y축이 표시되는 범위를 지정
# ▪ xlim()에 [xmin, xmax], ylim() [ymin,ymax)각각 지정 혹은,
# ▪ axis()함수에 [xmin, xmax, ymin,ymax] 의 형태로 범위를 지정
# ▪ axis()함수를 사용할 때는 반드시 네 개의 값 필요
# ▪ 입력이 없으면 자동으로 범위 지정

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.axis('auto')
plt.axis('scaled')

plt.show()

# %% [markdown]
# ### 축 범위 반환

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# xlim(), ylim()함수는 그래 프 영역에 표시되는 x축,y축의 범위를 각각 반환
# axis()함수는 그래프 영역 에 표시되는 x,y축의 범위 를 한번에 반환

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)

plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %% [markdown]
# ### 마커지정

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'vr--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis', rotation=360)
plt.show()

# %% [markdown]
# ### 색상지정

# %%
plt.plot([1, 2, 3, 4], [2, 2.5, 3.3, 4.5], 'r')
plt.plot([1, 2, 3, 4], [2, 2.8, 4.3, 6.5], 'g')
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'b')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
# color키워드 인자를 사용해서 더 다양한 색상 이름 지정 가능

plt.plot([1, 2, 3, 4], [2, 2.5, 3.3, 4.5], color='springgreen')
plt.plot([1, 2, 3, 4], [2, 2.8, 4.3, 6.5], color='violet')
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='dodgerblue')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
# 선의 색상은 Hex code로 표현도 가능

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#ff7f0e', marker='o', linestyle='--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### 그래프 일부 영역 채우기

# %%
# 특정 영역을 강조할 때 사용
# ■ 특정 영역만 채우는 세가지 함수,
# ■ fill_between(), 두 수평 방향의 곡선 사이를 채운다.
# ■ fill_betweenx(), 두 수직 방향의 곡선 사이를 채운다.
# ■ fill(), 다각형 영역을 채운다

# %%
x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# plt.fill_between(y[1:3], x[1:3], alpha=0.5)
plt.fill_between(y[2:4], x[2:4], color='pink', alpha=0.5)
plt.show()

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgrey', alpha=0.5)
plt.show()

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.fill_between(x[2:], y1[2:], y2[2:], color='lightgrey', alpha=0.5)
plt.show()

# %%
x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.fill_between([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgrey', alpha=0.5)
plt.show()

# %% [markdown]
# ### 여러 곡선 그리기

# %%
import numpy as np

a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'r--', a, a**2, 'bo', a, a**3, 'g-.')
plt.show()

# 하나의 그래프 영역에 여러 개 스타일의 곡선을 나타내는 방법을 소개
# - Numpy Array[0 0.2 0.4 0.6 0.8 1 1.2 1.4 1.6 1.8]
# - 세개의 곡선(y=x, y = x^2, y x^3)이 동시에 그려진다.
# - r- 빨간색 대시 , bo 파란색 원형, g- 녹색 대시-닷 스타일 선을 의미한다.

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='forestgreen', marker='^', markersize=9)
plt.show()

# %% [markdown]
# ### 그리드 Grid 설정

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True)
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')
plt.show()

# %% [markdown]
# ### 눈금 표시하기

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='forestgreen', marker='^', markersize=9)

# Tick 틱 은 그래프의 축에 간격을 구분하기 위해 표시하는 눈금
# xticks(), yticks(), tick_params()함수를 이용해서 그래프에 눈금 그림
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))
plt.show()

# %% [markdown]
# ### 눈금 레이블 지정

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='forestgreen', marker='^', markersize=9)

plt.xticks(np.arange(0,2,0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0, 7), ('0' '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))
plt.show()

# %% [markdown]
# ### 수직 막대 그래프

# %%
y = np.arange(3)
years = ['2018', '2019', '2020']
values =[100, 400, 900]

plt.barh(y, values, height=-0.6, align='edge', color='forestgreen', 
         edgecolor='gray', linewidth=3, tick_label=years, log=False)
plt.show()

# %% [markdown]
# ### 수평 막대 그래프

# %%
# 수평 막대 그래프 Horizontal bar graph 은 범주가 있는 데이터 값을 수평 막대로 표현하는 그래프
# years는 y축에 표시될 연도, values는 막대 그래프의 너비로 표시될 x값

y = np.arange(3)

years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values)
plt.yticks(y, years)

plt.show()

# %% [markdown]
# ### 산점도 Scatter plot

# %%
# 산점도는 두 변수의 상관 관계를 직교 좌표계의 평면에 점으로 표현하는 그래프
# scatter()함수를 사용하여 산점도를 그림
# NumPy의 random 모듈로 0,1범위의 난수를 생성


np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)

plt.scatter(x, y)
plt.show()

# %%
np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n)) ** 2    # 마커의 크기는 size**2의 형태로 지정
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors)     # scatter()함수의 s와 c 파라미터는 각각 마커의 크기와 색상을 지정
# 마커의 색상은 데이터의 길이와 같은 크기의 숫자 시퀀스 또는 rgb 그리고 hex code색상을 입력해서 지정
plt.show()

# %%
plt.plot([1], [1], 'o', markersize=20, c='#FF5733')
plt.scatter([2], [1], s=20**2, c='#33FFCE')

# plot함수의 markersize를 20으로 scatter()함수의 s값을 20**2 로 지정
# 동일한 크기의 마커가 표시
plt.text(0.5, 1.05, 'plot(markersize=20)', fontdict={'size':14})
plt.text(1.6, 1.05, 'scater(s=20**2)', fontdict={'size':14})
plt.axis([0.4, 2.6, 0.8, 1.2])
plt.show()

# %%
n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n)) ** 2
colors = np.random.rand(n)

# alpha 파라미터는 마커의 투명도를 지정. 0 ~ 1사이의 값으로 입력
# cmap 파라미터는 컬러맵에 해당하는 문자열을 지정
plt.scatter(x, y, s=area, c=colors, alpha=0.5, cmap='Spectral')
plt.colorbar()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D      # 3차원 그래프를 그리기 위해 추가
                                              # Matplotlib 3.1.0버전부터는 기본 포함

np.random.seed(0)

n = 100
x = np.random.rand(n)
y = np.random.rand(n)
z = np.random.rand(n)
area = (15 * np.random.rand(n)) ** 2
colors = np.random.rand(n)

fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot(111, projection='3d')    # 3d axes를 만들기 위해서 add_subplot()에 projection =‘3d’키워드를 입력

ax.scatter(x, y, z, s=area, c=colors, cmap='Spectral')
plt.show()

# %%
np.random.seed(0)
arr = np.random.standard_normal((8, 100))

plt.subplot(2, 2, 1)
plt.scatter(arr[0], arr[1], c=arr[1])
plt.spring()
plt.title('spring')

plt.subplot(2, 2, 2)
plt.scatter(arr[2], arr[3], c=arr[3])
plt.summer()
plt.title('summer')

plt.subplot(2, 2, 3)
plt.scatter(arr[4], arr[5], c=arr[5])
plt.autumn()
plt.title('autumn')

plt.subplot(2, 2, 4)
plt.scatter(arr[6], arr[7], c=arr[7])
plt.winter()
plt.title('winter')

plt.tight_layout()
plt.show()

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.rand(5000) - 10.0

plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
# text()함수를 이용해서 3개의 히스토그램 그래프에 설명을 위한 텍스트를 추가
# text()함수로 그래프 상의 x위치 y위치 그리고 삽입할 텍스트의 순서대로 입력
plt.text(1.0, 0.35, '2.0*np.random.randn(10000)+1.0')

plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.20, '2.0*np.random.randn(10000)+1.0')

plt.hist(a, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(5.0, 0.08, '2.0*np.random.randn(5000)+10.0')
plt.show()

# %%
a = 2.0 * np.random.randn(10000) + 1.0
b = np.random.standard_normal(10000)
c = 20.0 * np.random.rand(5000) - 10.0

font1 = {'family': 'serif',
        'color': 'darkred',
        'weight': 'normal',
        'size' : 16}
font2 = {'family': 'Times New Roman',
        'color': 'blue',
        'weight': 'bold',
        'size' : 12}
font3 = {'family': 'Arial',
        'color': 'forestgreen',
        'style': 'italic',
        'size' : 14}

# fontdict 키워드로 font 종류, 크기, 색상, 투명도, weight 등의 텍스트 스타일을 설정
plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')

# font1, font2, font3와 같이 리지정한 폰트 딕셔너리 입력
plt.text(1.0, 0.35, '2.0*np.random.randn(10000)+1.0', fontdict=font1)

plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.20, '2.0*np.random.randn(10000)+1.0', fontdict=font2)

plt.hist(a, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(5.0, 0.08, '2.0*np.random.randn(5000)+10.0', fontdict=font3)
plt.show()

# %%
plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(-3.0, 0.15, '2.0*np.random.randn(10000)+1.0', fontdict=font1, rotation=85)
# rotation 키워드를 이용해서 텍스트를 회전

plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.0, '2.0*np.random.randn(10000)+1.0', fontdict=font2, rotation=-60)

plt.hist(a, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(-10.0, 0.08, '2.0*np.random.randn(5000)+10.0', fontdict=font3)
plt.show()

# %%
box1 = {'boxstyle': 'round',
       'ec': (1.0, 0.5, 0.5),
       'fc': (1.0, 0.8, 0.8)}
box2 = {'boxstyle': 'square',
       'ec': (0.5, 0.5, 1.0),
       'fc': (0.8, 0.8, 1.0)}
box3 = {'boxstyle': 'square',
       'ec': (0.3, 1.0, 0.5),
       'fc': (0.8, 1.0, 0.5),
       'linestyle': '-.',
       'linewidth': 2}
plt.hist(a, bins=100, density=True, alpha=0.7, histtype='step')
plt.text(-3.0, 0.15, '2.0*np.random.randn(10000)+1.0', fontdict=font1, rotation=85, bbox=box1)

plt.hist(b, bins=50, density=True, alpha=0.5, histtype='stepfilled')
plt.text(2.0, 0.0, '2.0*np.random.randn(10000)+1.0', fontdict=font2, rotation=-60, bbox=box2)

plt.hist(a, bins=100, density=True, alpha=0.9, histtype='step')
plt.text(-10.0, 0.08, '2.0*np.random.randn(5000)+10.0', fontdict=font3, bbox=box3)
plt.show()

# %% [markdown]
# ### 객체 지향 인터페이스

# %%
# Matplotlib는 그래프를 다루는 두 가지 인터페이스를 제공
# – 첫 번째가 pyplot 모듈을 사용하는 방식
# – 두 번째는 객체 지향 인터페이스 
# 더욱 커스터마이즈 된 그래프를 표현하기 위해 객체 지향 인터페이스를 사용할 수 있음

# %%
fig = plt.figure()                  # 액자
ax = fig.add_axes([0, 0, 1, 1])     # 도화지
plt.show()

# %%
fig, ax = plt.subplots()          # 액자와 도화지를 동시에
plt.show()

# subplot()함수를 호출하면 figure(fig)와 subplot(ax)객체를 생성해서 튜플 형태로 반환
# plt.figure()는 Figure클래스의 인스턴스를 반환
# Figure 클래스의 인스턴스 fig의 메서드 add_axes()는 axes를 하나 추가
# add_axes([left, bottom, width, height]) 의 형태로
# 0에서 1 사이의 값을 입력하면 그 값에 따라 이미지의 크기가 결정됨

# %%
# plt.subplots(행, 열) 형태로 행과 열의 개수를 지정
# 지정하지 않으면 기본적으로 행과 열의 개수는 모두 1

fig, ax = plt.subplots(2, 2)
plt.show()

# %%
# sharex= True, sharey=True 를 설정하여 중복된 축을 한번만 표시
# 이외에도 all, none, row, col 등을 지정하여 사용
fig, ax = plt.subplots(2, 2, sharex=True, sharey=True)
plt.show()

# %%
x = np.arange(1, 5)


# NumPy를 이용해서 x값을 만들어 네 개의 그래프 영역에 각각 다른 y값을 그래프 표시
fig, ax = plt.subplots(2, 2, sharex=True, sharey=True, squeeze=True)
ax[0][0].plot(x, np.sqrt(x))         # left-top
ax[0][1].plot(x, x)                  # right-top
ax[1][0].plot(x, -x+5)               # left-bottom
ax[1][1].plot(x, np.sqrt(-x+5))      # right-bottom
plt.show()

# %%
# plot()함수에 각각의 그래프 스타일을 커스터마이즈

x = np.arange(1, 5)


fig, ax = plt.subplots(2, 2, sharex=True, sharey=True, squeeze=True)
ax[0][0].plot(x, np.sqrt(x), 'gray', linewidth=3)         # left-top
ax[0][1].plot(x, x, 'g^-', markersize=10)                  # right-top
ax[1][0].plot(x, -x+5, 'ro--')               # left-bottom
ax[1][1].plot(x, np.sqrt(-x+5), 'b.-.')      # right-bottom
plt.show()

# %% [markdown]
# ### 축 위치 조절

# %%
# Matplotlib의 기본적인 레이아웃은 그래프 상하좌우의 네 방향에 데이터 영역을 나타내는 직선이 그려지는 형태
# 데이터 영역을 나타내는 직선을 필요한 위치에 선택적으로 표시하는 방법을 알아보자.

# %%
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

x = np.arange(0, 3)
y1 = x + 1
y2 = -x -1

fig, ax1 = plt.subplots()
ax1.plot(x, y1, color='green')

ax2 = ax1.twinx()
ax2.plot(x, y2, color='deeppink')
plt.show()

# %% [markdown]
# ### 두 종류의 그래프 그리기

# %%
# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
x = np.arange(2020, 2027)
y1 = np.array([1, 3, 7, 5, 9, 7, 14])
y2 = np.array([1, 3, 5, 7, 9, 11, 13])

# 3. 그래프 그리기
fig, ax1 = plt.subplots()

ax1.plot(x, y1, '-s', color='green', markersize=7, linewidth=5, alpha=0.7, label='Price')
ax1.set_ylim(0, 18)
ax1.set_xlabel('Year')
ax1.set_ylabel('Price ($)')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.bar(x, y2, color='deeppink', label='Demand', alpha=0.7, width=0.7)
ax2.set_ylim(0, 18)
ax2.set_ylabel(r'Demand ($|times10^6$)')
ax2.tick_params(axis='y', direction='in')

plt.show()
